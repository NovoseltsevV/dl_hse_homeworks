# %% [markdown]
# # Глубинное обучение 1 / Введение в глубинное обучение, ФКН ВШЭ
#
# ## Домашнее задание 1. Часть 2: полносвязные нейронные сети.
#
# ### Общая информация
#
# Оценка после штрафа после мягкого дедлайна вычисляется по формуле $M_{\text{penalty}} = M_{\text{full}} \cdot 0.85^{t/1440}$, где $M_{\text{full}}$ — полная оценка за работу без учета штрафа, а $t$ — время в минутах, прошедшее после мягкого дедлайна (округление до двух цифр после запятой). Таким образом, спустя первые сутки после мягкого дедлайна вы не можете получить оценку выше 8.5, а если сдать через четыре дня после мягкого дедлайна, то ваш максимум — 5.22 балла.
#
# ### Оценивание и штрафы
#
# Максимально допустимая оценка за работу — 10 баллов. Сдавать задание после указанного срока сдачи нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке. Также оценка может быть снижена за плохо читаемый код и плохо оформленные графики. Все ответы должны сопровождаться кодом или комментариями о том, как они были получены.
#
# ### О задании
#
# В этой части мы будем использовать фреймворк для обучения нейронный сетей, который вы реализовали в первой половине задания. А именно, вам предстоит обучить полносвязную нейронную сеть для предсказания года выпуска песни по ее аудио-признакам. Для этого мы будем использовать [Million Songs Dataset](https://samyzaf.com/ML/song_year/song_year.html). Если по какой-то причине вы не сделали первую половину домашки, то **можете поставить все эксперименты на PyTorch**, но рекомендуется использовать ваши реализации модулей.

# %%
import modules as mm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from IPython.display import clear_output

plt.rcParams.update({'font.size': 16})
sns.set_style('whitegrid')
np.random.seed(0xFA1AFE1)

# %% [markdown]
# Начнем с того, что скачаем и загрузим данные:

# %%
# !wget -O data.txt.zip https://archive.ics.uci.edu/ml/machine-learning-databases/00203/YearPredictionMSD.txt.zip
# Out:
# --2025-04-30 20:29:08--  https://archive.ics.uci.edu/ml/machine-learning-databases/00203/YearPredictionMSD.txt.zip
# Распознаётся archive.ics.uci.edu (archive.ics.uci.edu)… 128.195.10.252
# Подключение к archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: нет данных
# Сохранение в: «data.txt.zip»
#
# data.txt.zip            [    <=>             ] 201,24M   572KB/s    за 5m 19s
#
# 2025-04-30 20:34:29 (646 KB/s) - «data.txt.zip» сохранён [211011981]

# %%
df = pd.read_csv('data.txt.zip', header=None)
df
# Out:
#           0         1         2         3         4         5         6   \
# 0       2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1       2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2       2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3       2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4       2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409
# ...      ...       ...       ...       ...       ...       ...       ...
# 515340  2006  51.28467  45.88068  22.19582  -5.53319  -3.61835 -16.36914
# 515341  2006  49.87870  37.93125  18.65987  -3.63581 -27.75665 -18.52988
# 515342  2006  45.12852  12.65758 -38.72018   8.80882 -29.29985  -2.28706
# max       335.771820     262.068870     166.236890     172.402680
#
#                   8              9   ...             81             82  \
# count  515345.000000  515345.000000  ...  515345.000000  515345.000000
# mean       -1.793236       3.727876  ...      15.755406     -73.461500
# std         7.963827      10.582861  ...      32.099635     175.618889
# min       -72.503850    -126.479040  ...    -437.722030   -4402.376440
# 25%        -6.468420      -2.293660  ...      -1.812650    -139.555160
# 50%        -1.736450       3.822310  ...       9.171850     -53.090060
# 75%         2.913450       9.961820  ...      26.274480      13.478730
# max       126.741270     146.297950  ...     840.973380    4469.454870
#
#                   83             84             85             86  \
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean       41.542422      37.934119       0.315751      17.669213
# std       122.228799      95.050631      16.161764     114.427905
# min     -1810.689190   -3098.350310    -341.789120   -3168.924570
# 25%       -20.986900      -4.669540      -6.781590     -31.580610
# 50%        28.791060      33.623630       0.820840      15.598470
# 75%        89.661770      77.785800       8.470990      67.794960
# max      3210.701700    1734.079690     260.544900    3662.065650
#
#                   87             88             89             90
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean      -26.315336       4.458641      20.035136       1.329105
# std       173.977336      13.346557     185.558247      22.088576
# min     -4319.992320    -236.039260   -7458.378150    -381.424430
# 25%      -101.530300      -2.566090     -59.509270      -8.820210
# 50%       -21.204120       3.117640       7.759730       0.053050
# 75%        52.389330       9.967740      86.351610       9.679520
# max      2833.608950     463.419500    7393.398440     677.899630
#
# [8 rows x 91 columns]

# %% [markdown]
# Целевая переменная, год выпуска песни, записана в первом столбце. Посмотрим на ее распределение.

# %%
plt.hist(df.iloc[:, 0], bins=20)
plt.xlabel('year')
plt.ylabel('count')
plt.show()
print(f'Range: {df.iloc[:, 0].min()} - {df.iloc[:, 0].max()}')
print(f'Unique values: {np.unique(df.iloc[:, 0]).size}')
# Out:
# Range: 1922 - 2011
# Unique values: 89

# %% [markdown]
# Разобьем данные на обучение и тест (не меняйте здесь ничего, чтобы сплит был одинаковым у всех).

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

train_size = int(0.75 * X.shape[0])
X_train = X[:train_size, :]
y_train = y[:train_size]
X_test = X[train_size:, :]
y_test = y[train_size:]
X_train.shape, X_test.shape
# Out:
# ((386508, 90), (128837, 90))

# %% [markdown]
# **Задание 0 (0 баллов, но при невыполнении максимальная оценка за всю работу &mdash; 0 баллов).** Мы будем использовать MSE как метрику качества. Прежде чем обучать нейронные сети, нам нужно проверить несколько простых бейзлайнов, чтобы было с чем сравнить более сложные алгоритмы. Для этого бучите `Ridge` регрессию из `sklearn`. Кроме того, посчитайте качество при наилучшем константном прогнозе.

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

ridge_model = Ridge(random_state=42)
_ = ridge_model.fit(X_train, y_train)
ridge_pred = ridge_model.predict(X_test)
print(f'Ridge model MSE: {mean_squared_error(y_test, ridge_pred)}')
# Out:
# Ridge model MSE: 89.74966397222076

# %%
constant_pred = np.mean(y_train) * np.ones_like(y_test)
print(f'Constant model MSE: {mean_squared_error(y_test, constant_pred)}')
# Out:
# Constant model MSE: 117.62580230734426

# %% [markdown]
# Теперь приступим к экспериментам с нейросетями. Для начала отделим от данных валидацию:

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=0xE2E4)
X_train.shape, X_val.shape
# Out:
# ((289881, 90), (96627, 90))

# %% [markdown]
# ## Глава I. Заводим нейронную сеть (5 баллов)
#
# **Задание 1.1 (0.5 баллов).** Заполните пропуски в функции `train_and_validate`. Она поможет нам запускать эксперименты.

# %%
def plot_losses(train_losses, train_metrics, val_losses, val_metrics):
    """
    Plot losses and metrics while training
      - train_losses: sequence of train losses
      - train_metrics: sequence of train MSE values
      - val_losses: sequence of validation losses
      - val_metrics: sequence of validation MSE values
    """
    clear_output()
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    axs[0].plot(range(1, len(train_losses) + 1), train_losses, label='train')
    axs[0].plot(range(1, len(val_losses) + 1), val_losses, label='val')
    axs[1].plot(range(1, len(train_metrics) + 1), train_metrics, label='train')
    axs[1].plot(range(1, len(val_metrics) + 1), val_metrics, label='val')

    if max(train_losses) / min(train_losses) > 10:
        axs[0].set_yscale('log')

    if max(train_metrics) / min(train_metrics) > 10:
        axs[1].set_yscale('log')

    for ax in axs:
        ax.set_xlabel('epoch')
        ax.legend()

    axs[0].set_ylabel('loss')
    axs[1].set_ylabel('MSE')
    plt.show()


def train_and_validate(model, optimizer, criterion, metric, train_loader, val_loader,
                       num_epochs, verbose=True):
    """
    Train and validate neural network
      - model: neural network (mm.Module) to train
      - optimizer: optimizer (mm.Optimizer) chained to a model
      - criterion: loss function class (mm.Criterion)
      - metrics: function to measure MSE taking neural networks predictions
                 and ground truth labels
      - train_loader: mm.DataLoader with train set
      - val_loader: mm.DataLoader with validation set
      - num_epochs: number of epochs to train
      - verbose: whether to plot metrics during training
    Returns:
      - train_mse: training MSE over the last epoch
      - val_mse: validation MSE after the last epoch
    """
    train_losses, val_losses = [], []
    train_metrics, val_metrics = [], []

    for epoch in range(1, num_epochs + 1):
        model.train()
        running_loss, running_metric = 0, 0
        pbar = tqdm(train_loader, desc=f'Training {epoch}/{num_epochs}') \
            if verbose else train_loader

        for X_batch, y_batch in pbar:
            predictions = model(X_batch)
            optimizer.zero_grad()
            loss = criterion(predictions, y_batch)
            model.backward(X_batch, criterion.backward(predictions, y_batch))
            optimizer.step()

            metric_value = metric(predictions, y_batch)
            running_loss += loss * X_batch.shape[0]
            running_metric += metric_value * X_batch.shape[0]
            if verbose:
                pbar.set_postfix({'loss': loss, 'MSE': metric_value})

        train_losses += [running_loss / train_loader.num_samples()]
        train_metrics += [running_metric / train_loader.num_samples()]

        model.eval()
        running_loss, running_metric = 0, 0
        pbar = tqdm(val_loader, desc=f'Validating {epoch}/{num_epochs}') \
            if verbose else val_loader

        for X_batch, y_batch in pbar:

            predictions = model(X_batch)
            loss = criterion(predictions, y_batch)

            metric_value = metric(predictions, y_batch)
            running_loss += loss * X_batch.shape[0]
            running_metric += metric_value * X_batch.shape[0]
            if verbose:
                pbar.set_postfix({'loss': loss, 'MSE': metric_value})

        val_losses += [running_loss / val_loader.num_samples()]
        val_metrics += [running_metric / val_loader.num_samples()]

        if verbose:
            plot_losses(train_losses, train_metrics, val_losses, val_metrics)
    
    if verbose:
        print(f'Validation MSE: {val_metrics[-1]:.3f}')
    
    return train_metrics[-1], val_metrics[-1]

# %% [markdown]
# **Задание 1.2 (0.75 балла).** Попробуем обучить нашу первую нейронную сеть. Здесь целевая переменная дискретная &mdash; это год выпуска песни. Поэтому будем учить сеть на классификацию.
#
# - В качестве архитектуры сети возьмите два линейных слоя с активацией ReLU между ними c числом скрытых нейронов, равным 128.
# - Используйте SGD с `lr=1e-3`.
# - Возьмите размер мини-батча около 32-64, примерно 3-4 эпох обучения должно быть достаточно.
# - Также преобразуйте целевую переменную так, чтобы ее значения принимали значения от $0$ до $C-1$, где $C$ &mdash; число классов (лучше передайте преобразованное значение в DataLoader, исходное нам еще пригодится)
# - В качестве параметра `metric` в `train_and_validate` передайте lambda-выражение, которое считает MSE по выходу нейронной сети и целевой переменной. В случае классификации предсказывается класс с наибольшей вероятностью (или, что то же самое, с наибольшим значением логита).

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y)
train_loader = mm.DataLoader(X_train, le.transform(y_train), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(X_val, le.transform(y_val), batch_size=64, shuffle=False)

# %%
num_classes = len(np.unique(y))

class_model = mm.Sequential(
    mm.Linear(90, 128),
    mm.ReLU(),
    mm.Linear(128, num_classes)
)

criterion = mm.CrossEntropyLoss()
optimizer = mm.SGD(class_model, lr=1e-3)
metric = lambda x, y: mean_squared_error(y, np.argmax(x, axis=1))

# %%
train_and_validate(class_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=5)
# Out:
# Validation MSE: 195.267
# (191.05788237242177, 195.26711995611993)

# %% [markdown]
# **Задание 1.3 (0.5 балла).** Прокомментируйте ваши наблюдения. Удалось ли побить бейзлайн? Как вы думаете, хорошая ли идея учить классификатор для этой задачи? Почему?
#
# **Ответ:** Не удалось даже побить константное предсказание, что говорит о том, что учить классификатор в этой задаче неправильно. Очевидно, что на годах выпуска песен есть расстояние, информация о котором полностью теряется при переходе к классам.

# %% [markdown]
# **Задание 1.4 (0.75 балла).** Теперь попробуем решать задачу как регрессию. Обучите нейронную сеть на MSE.
#
# - Используйте такие же гиперпараметры обучения.
# - Когда передаете целевую переменную в DataLoader, сделайте reshape в (-1, 1).
# - Не забудьте изменить lambda-выражение, которые вы передаете в `train_and_validate`.
# - Если что-то пойдет не так, можете попробовать меньшие значения `lr`.

# %%
train_loader = mm.DataLoader(X_train, y_train.reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(X_val, y_val.reshape((-1, 1)), batch_size=64, shuffle=False)

reg_model = mm.Sequential(
    mm.Linear(90, 128),
    mm.ReLU(),
    mm.Linear(128, 1)
)

criterion = mm.MSELoss()
optimizer = mm.SGD(reg_model, lr=1e-3)
metric = mm.MSELoss()
train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=5)
# Out:
# Validation MSE: 23380629133949287342606753135037127063502848.000
#           1.50433568e+05,  4.91540021e+00, -6.02782230e+13,
#          -3.53758417e+13,  4.92533893e+02, -2.35209965e+13,
#           1.94301210e+02, -3.34040319e+36,  1.07219949e+38,
#           1.54391946e+38,  1.24119942e+05, -5.09765060e+14,
#           1.70406492e+03,  3.41269274e+01,  4.63913118e+02,
#           3.48120041e+02,  7.59215558e+01,  1.66562787e+02,
#          -1.95756338e+11, -2.47152583e+13]]),
#  array([-4.83535202e+21])]

# %% [markdown]
# **Задание 1.5 (0.5 балла).** Получилось ли у вас стабилизировать обучение? Помогли ли меньшие значения `lr`? Стало ли лучше от замены классификации на регрессию? Как вы думаете, почему так происходит? В качестве подсказки можете посмотреть на распределение целевой переменной и магнитуду значений признаков.
#
# **Ответ:** Стабильность обучения сильно зависит от начальной инициализации параметров, так как входящие признаки бывают очень большие по модулю, а также часто разного масштаба. Пока регрессия работает сильно хуже, но это объясняется тем, что изначальные признаки не были отнормированы, и как следствие веса в модели очень нестабильные и большие по модулю. Также сама целевая переменная имеет распределение около тысяч, что сложно подобрать, начиная с ответов около нуля

# %% [markdown]
# **Задание 1.6 (0.75 балла).** Начнем с того, что попробуем отнормировать целевую переменную. Для этого воспользуемся min-max нормализацией, чтобы целевая переменная принимала значения от 0 до 1. Реализуйте функции `normalize` и `denormalize`, которые, соответственно, нормируют целевую переменную и применяют обратное преобразование. Минимум и максимум оцените по обучающей выборке (то есть эти константы должны быть фиксированными и не зависеть от передаваемой выборки).

# %%
min_train = np.min(y_train)
max_train = np.max(y_train)

def normalize(sample):
    """
    Min-max normalization to convert sample to [0, 1] range
    """
    return (sample - min_train) / (max_train - min_train)

def denormalize(sample):
    """
    Denormalize sample from [0, 1] to initial range
    """
    return (max_train - min_train) * sample + min_train

# %% [markdown]
# Теперь повторите эксперимент из **задания 1.4**, обучаясь на нормированной целевой переменной. Сделаем также еще одно изменение: добавим сигмоидную активацию после последнего линейного слоя сети. Таким образом мы гарантируем, что нейронная сеть предсказывает числа из промежутка $[0, 1]$. Использование активации - довольно распространенный прием, когда мы хотим получить числа из определенного диапазона значений.

# %%
train_loader = mm.DataLoader(X_train, normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(X_val, normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

reg_model = mm.Sequential(
    mm.Linear(90, 128),
    mm.ReLU(),
    mm.Linear(128, 1),
    mm.Sigmoid()
)

criterion = mm.MSELoss()
optimizer = mm.SGD(reg_model, lr=1e-5)
metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=5)
# Out:
# Validation MSE: 283.385
# (284.11287086173314, 283.38535228659464)

# %% [markdown]
# **Задание 1.7 (0.5 балла).** Сравните результаты этого эксперимента с предыдущим запуском.
#
# **Ответ:** результаты стали гораздо лучше, правда теперь при обучении появляются warningы о перпеполнении памяти при вычислении градиентов сигмоиды, так как всё ещё признаки не были отнормированы

# %% [markdown]
# **Задание 1.8 (0.75 балла).** На этот раз попробуем отнормировать не только целевую переменную, но и сами данные, которые подаются сети на вход. Для них будем использовать нормализацию через среднее и стандартное отклонение. Преобразуйте данные и повторите прошлый эксперимент. Скорее всего, имеет смысл увеличить число эпох обучения.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

reg_model = mm.Sequential(
    mm.Linear(90, 128),
    mm.ReLU(),
    mm.Linear(128, 1),
    mm.Sigmoid()
)

criterion = mm.MSELoss()
optimizer = mm.SGD(reg_model, lr=1e-2)
metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
# Out:
# Validation MSE: 89.882
# (89.24892347159874, 89.88192133748159)

# %%
network_pred = denormalize(reg_model(scaler.transform(X_test)))
print(f'Network MSE: {mean_squared_error(y_test, network_pred)}')
# Out:
# Network MSE: 87.81666383389447

# %% [markdown]
# В итоге получили качество чуть лучше, чем у Ridge регрессии

# %% [markdown]
# Если вы все сделали правильно, то у вас должно было получиться качество, сравнимое с `Ridge` регрессией.
#
# **Мораль:** как видите, нам пришлось сделать очень много хитрых телодвижений, чтобы нейронная сеть работала хотя бы так же, как и простая линейная модель. Здесь, конечно, показан совсем экстремальный случай, когда без нормализации данных нейронная сеть просто не учится. Как правило, в реальности завести нейронную сеть из коробки не очень сложно, но вот заставить ее работать на полную &mdash; куда более трудоемкая задача. Написание пайплайнов обучения нейросетевых моделей требует большой аккуратности, а дебаг часто превращается в угадайку. К счастью, очень часто на помощь приходит интуиция, и мы надеемся, что вы сможете выработать ее в течение нашего курса. Начнем с двух советов, которые стоит принять на вооружение:
#
# - Обязательно начинаем любые эксперименты с бейзлайнов: без них мы бы не поняли, что нейронная сеть не учится в принципе.
# - При постановке эксперментов старайтесь делать минимальное количество изменений за раз (в идеале одно!): только так можно понять, какие конкретно изменения влияют на результат.

# %% [markdown]
# ## Часть 2. Улучшаем нейронную сеть
#
# Продолжим экспериментировать с нейронной сетью, чтобы добиться еще лучшего качества. В заданиях 2.1-2.3 **запускайте эксперименты несколько раз (4-5)** с одинаковыми значениями гиперпараметров обучения, но с разными случайными инициализациями сети (достаточно просто прогнать код с инициализацией модели и ее обучением в цикле: каждый вызов конструктора инициализирует модель случайно). Для сравнения качества разных экспериментов **отрисовывайте ящики с усами (boxplot)** по этим нескольким запускам.
#
# Задание 2.4 требует перебора гиперпараметров, в нем запускайте эксперимент по одному разу для каждого рассмотренного значения, чтобы сэкономить время.

# %% [markdown]
# **Задание 2.1 (1 балл).** Давайте попробуем другие оптимизаторы. Обучите нейросеть с помощью SGD+momentum и Adam. Опишите свои наблюдения и в дальнейших запусках используйте лучший оптимизатор. Для Adam обычно берут learning rate поменьше, в районе $10^{-3}$.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

sgd_train_mse = []
sgd_val_mse = []
sgd_test_mse = []

for i in range(5):
    reg_model = mm.Sequential(
        mm.Linear(90, 128),
        mm.ReLU(),
        mm.Linear(128, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.SGD(reg_model, lr=1e-1)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    sgd_train_mse.append(train_mse)
    sgd_val_mse.append(val_mse)
    sgd_test_mse.append(test_mse)
# Out:
# Validation MSE: 80.831

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

adam_train_mse = []
adam_val_mse = []
adam_test_mse = []

for i in range(5):
    reg_model = mm.Sequential(
        mm.Linear(90, 128),
        mm.ReLU(),
        mm.Linear(128, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.Adam(reg_model, lr=1e-3)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    adam_train_mse.append(train_mse)
    adam_val_mse.append(val_mse)
    adam_test_mse.append(test_mse)
# Out:
# Validation MSE: 77.285

# %%
data = {
    'Optimizer': ['SGD']*5 + ['Adam']*5,
    'Train MSE': sgd_train_mse + adam_train_mse,
    'Val MSE': sgd_val_mse + adam_val_mse,
    'Test MSE': sgd_test_mse + adam_test_mse
}

df = pd.DataFrame(data)

df_melted = pd.melt(df, 
                    id_vars=['Optimizer'], 
                    value_vars=['Train MSE', 'Val MSE', 'Test MSE'],
                    var_name='Metric', 
                    value_name='MSE')

plt.figure(figsize=(12, 6))

ax = sns.boxplot(x='Metric', y='MSE', hue='Optimizer', 
                 data=df_melted, width=0.6, linewidth=1.5)

plt.title('Сравнение стабильности SGD и Adam по MSE', pad=20)
plt.xlabel('')
plt.ylabel('Mean Squared Error', labelpad=10)
plt.legend(title='Optimizer', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Статистически заметно, что Адам сходится к лучшему минимуму, однако он больше подвержен влиянию начальной инициализации, так как ящики с усами для него шире, чем для SGD, который каждый раз сходится примрено в одну и ту же точку

# %% [markdown]
# **Задание 2.2 (1 балл).** Теперь сделаем нашу нейронную сеть более сложной. Попробуйте сделать сеть:
#
# - более широкой (то есть увеличить размерность скрытого слоя, например, вдвое)
# - более глубокой (то есть добавить еще один скрытый слой)
#
# Опишите, как увеличение числа параметров модели влияет на качество на обучающей и валидационной выборках.

# %% [markdown]
# __Широкая сеть__

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

wide_train_mse = []
wide_val_mse = []
wide_test_mse = []

for i in range(3):
    reg_model = mm.Sequential(
        mm.Linear(90, 256),
        mm.ReLU(),
        mm.Linear(256, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.Adam(reg_model, lr=1e-3)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    wide_train_mse.append(train_mse)
    wide_val_mse.append(val_mse)
    wide_test_mse.append(test_mse)
# Out:
# Validation MSE: 77.816

# %% [markdown]
# __Глубокая сеть__

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

deep_train_mse = []
deep_val_mse = []
deep_test_mse = []

for i in range(3):
    reg_model = mm.Sequential(
        mm.Linear(90, 128),
        mm.ReLU(),
        mm.Linear(128, 128),
        mm.ReLU(),
        mm.Linear(128, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.Adam(reg_model, lr=1e-3)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    deep_train_mse.append(train_mse)
    deep_val_mse.append(val_mse)
    deep_test_mse.append(test_mse)
# Out:
# Validation MSE: 77.105

# %%
data = {
    'Type': ['wide']*3 + ['deep']*3,
    'Train MSE': wide_train_mse + deep_train_mse,
    'Val MSE': wide_val_mse + deep_val_mse,
    'Test MSE': wide_test_mse + deep_test_mse
}

df = pd.DataFrame(data)

df_melted = pd.melt(df, 
                    id_vars=['Type'], 
                    value_vars=['Train MSE', 'Val MSE', 'Test MSE'],
                    var_name='Metric', 
                    value_name='MSE')

plt.figure(figsize=(12, 6))

ax = sns.boxplot(x='Metric', y='MSE', hue='Type', 
                 data=df_melted, width=0.6, linewidth=1.5)

plt.title('Сравнение стабильности Deep и Wide по MSE', pad=20)
plt.xlabel('')
plt.ylabel('Mean Squared Error', labelpad=10)
plt.legend(title='Type', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Видим, что глубокая сеть сильнее переобучается, однако несмотря на это, более стабильно сходится к лучшему качеству на валидации и тесте. Поэтому дальше будем работать только с глубокой моделью

# %% [markdown]
# **Задание 2.3 (1 балл).** Как вы должны были заметить, более сложная модель стала сильнее переобучаться. Попробуем разные методы регуляризации, чтобы бороться с переобучением. Проведите два эксперимента:
#
# - Добавьте слой дропаута с параметром $p=0.2$ после каждого линейного слоя, кроме последнего.
# - Попробуйте batch-нормализацию вместо дропаута. Строго говоря, batch-нормализация не является методом регуляризации, но никто не запрещает нам экспериментировать с ней.
#
# Опишите результаты экспериментов.

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

dropout_train_mse = []
dropout_val_mse = []
dropout_test_mse = []

for i in range(3):
    reg_model = mm.Sequential(
        mm.Linear(90, 128),
        mm.Dropout(p=0.2),
        mm.ReLU(),
        mm.Linear(128, 128),
        mm.Dropout(p=0.2),
        mm.ReLU(),
        mm.Linear(128, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.Adam(reg_model, lr=1e-3)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    dropout_train_mse.append(train_mse)
    dropout_val_mse.append(val_mse)
    dropout_test_mse.append(test_mse)
# Out:
# Validation MSE: 76.769

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

batchnorm_train_mse = []
batchnorm_val_mse = []
batchnorm_test_mse = []

for i in range(3):
    reg_model = mm.Sequential(
        mm.Linear(90, 128),
        mm.BatchNormalization(num_features=128),
        mm.ReLU(),
        mm.Linear(128, 128),
        mm.BatchNormalization(num_features=128),
        mm.ReLU(),
        mm.Linear(128, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.Adam(reg_model, lr=1e-3)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    batchnorm_train_mse.append(train_mse)
    batchnorm_val_mse.append(val_mse)
    batchnorm_test_mse.append(test_mse)
# Out:
# Validation MSE: 74.644

# %%
data = {
    'Type': ['dropout']*3 + ['batchnorm']*3,
    'Train MSE': dropout_train_mse + batchnorm_train_mse,
    'Val MSE': dropout_val_mse + batchnorm_val_mse,
    'Test MSE': dropout_test_mse + batchnorm_test_mse
}

df = pd.DataFrame(data)

df_melted = pd.melt(df, 
                    id_vars=['Type'], 
                    value_vars=['Train MSE', 'Val MSE', 'Test MSE'],
                    var_name='Metric', 
                    value_name='MSE')

plt.figure(figsize=(12, 6))

ax = sns.boxplot(x='Metric', y='MSE', hue='Type', 
                 data=df_melted, width=0.6, linewidth=1.5)

plt.title('Сравнение стабильности Dropout и Batchnorm по MSE', pad=20)
plt.xlabel('')
plt.ylabel('Mean Squared Error', labelpad=10)
plt.legend(title='Type', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# По графикам видно, что дропаут намного меньше переобучается. Поэтому несмотря на проигрыш на валидации по сравнению с батчнорм, его качество на тесте лучше. Поэтому далее будем оптимизировать сеть с дропаутом

# %% [markdown]
# **Задание 2.4 (1.5 балла).** Теперь, когда мы определились с выбором архитектуры нейронной сети, пора заняться рутиной DL-инженера &mdash; перебором гиперпараметров. Подберите оптимальное значение lr по значению MSE на валидации (по логарифмической сетке, достаточно посмотреть 3-4 значения), можете воспользоваться `verbose=False` в функции `train_and_validate`. Затем подберите оптимальное значение weight decay для данного lr (тоже по логарифмической сетке, типичные значения этого параметра лежат в диапазоне $[10^{-6}, 10^{-3}]$, но не забудьте включить нулевое значение в сетку). Постройте графики зависимости MSE на трейне и на валидации от значений параметров. Прокомментируйте получившиеся зависимости.

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

lr_train_mse = []
lr_val_mse = []
lr_test_mse = []

lr_arr = np.logspace(-5, -2, 5)

for lr in lr_arr:
    reg_model = mm.Sequential(
        mm.Linear(90, 128),
        mm.Dropout(p=0.2),
        mm.ReLU(),
        mm.Linear(128, 128),
        mm.Dropout(p=0.2),
        mm.ReLU(),
        mm.Linear(128, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.Adam(reg_model, lr=lr)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    lr_train_mse.append(train_mse)
    lr_val_mse.append(val_mse)
    lr_test_mse.append(test_mse)
# Out:
# Validation MSE: 80.811

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(lr_arr, lr_train_mse, label='train')
ax.plot(lr_arr, lr_val_mse, label='val')
ax.plot(lr_arr, lr_test_mse, label='test')

ax.set_xscale('log')
ax.legend()
plt.tight_layout()
plt.show()

# %%
best_lr = lr_arr[np.argmin(lr_val_mse)]
print(f'best lr: {best_lr}')
# Out:
# best lr: 0.00031622776601683794

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_val), normalize(y_val).reshape((-1, 1)), batch_size=64, shuffle=False)

wd_train_mse = []
wd_val_mse = []
wd_test_mse = []

wd_arr = np.r_[np.logspace(-6, -3, 4), np.array([0])]

for wd in wd_arr:
    reg_model = mm.Sequential(
        mm.Linear(90, 128),
        mm.Dropout(p=0.2),
        mm.ReLU(),
        mm.Linear(128, 128),
        mm.Dropout(p=0.2),
        mm.ReLU(),
        mm.Linear(128, 1),
        mm.Sigmoid()
    )

    criterion = mm.MSELoss()
    optimizer = mm.Adam(reg_model, lr=best_lr, weight_decay=wd)
    metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
    train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
    network_pred = denormalize(reg_model(scaler.transform(X_test)))
    test_mse = mean_squared_error(y_test, network_pred)
    wd_train_mse.append(train_mse)
    wd_val_mse.append(val_mse)
    wd_test_mse.append(test_mse)
# Out:
# Validation MSE: 76.152

# %%
best_wd = wd_arr[np.argmin(wd_val_mse)]
print(f'best wd: {best_wd}')
# Out:
# best wd: 1e-05

# %% [markdown]
# Зависимости качества от гиперпараметров получились именно такими, какие и ожидались из теоретических соображений

# %% [markdown]
# Как вы могли заметить, еще одна рутина DL-инженера &mdash; утомительное ожидание обучения моделей.
#
# **Задание 2.5 (0.5 балла).** Мы провели большое число экспериментов и подобрали оптимальную архитектуру и гиперпараметры. Пришло время обучить модель на полной обучающей выборке, померять качество на тестовой выборке и сравнить с бейзлайнами. Проделайте это.

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

train_size = int(0.75 * X.shape[0])
X_train = X[:train_size, :]
y_train = y[:train_size]
X_test = X[train_size:, :]
y_test = y[train_size:]

# %%
scaler = StandardScaler()
scaler.fit(X_train, y_train)

train_loader = mm.DataLoader(scaler.transform(X_train), normalize(y_train).reshape((-1, 1)), batch_size=64, shuffle=True)
val_loader = mm.DataLoader(scaler.transform(X_test), normalize(y_test).reshape((-1, 1)), batch_size=64, shuffle=False)

reg_model = mm.Sequential(
    mm.Linear(90, 128),
    mm.Dropout(p=0.2),
    mm.ReLU(),
    mm.Linear(128, 128),
    mm.Dropout(p=0.2),
    mm.ReLU(),
    mm.Linear(128, 1),
    mm.Sigmoid()
)

criterion = mm.MSELoss()
optimizer = mm.Adam(reg_model, lr=best_lr, weight_decay=best_wd)
metric = lambda x, y: mean_squared_error(denormalize(x), denormalize(y))
train_mse, val_mse = train_and_validate(reg_model, optimizer, criterion, metric, train_loader, val_loader, num_epochs=10)
network_pred = denormalize(reg_model(scaler.transform(X_test)))
test_mse = mean_squared_error(y_test, network_pred)
print(f'Best test MSE: {test_mse:.2f}')
print(f'Best test RMSE: {np.sqrt(test_mse):.2f}')
# Out:
# Validation MSE: 75.004
# Best test MSE: 75.00
# Best test RMSE: 8.66
